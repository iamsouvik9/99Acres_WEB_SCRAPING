# %% [markdown]
#
#
#                                                                  **WHAT IS WEB  SCRAPING?**
#
#
#
# Web scraping is an automatic method to obtain large amounts of data from websites. Most of this data is unstructured data in an HTML format which is then converted into structured data in a spreadsheet or a database so that it can be used in various applications. There are many different ways to perform web scraping to obtain data from websites. These include using online services, particular API’s or even creating your code for web scraping from scratch. Many large websites, like Google, Twitter, Facebook, StackOverflow, etc. have API’s that allow you to access their data in a structured format. This is the best option, but there are other sites that don’t allow users to access large amounts of data in a structured form or they are simply not that technologically advanced. In that situation, it’s best to use Web Scraping to scrape the website for data.
#
# Web scraping requires two parts, namely the crawler and the scraper. The crawler is an artificial intelligence algorithm that browses the web to search for the particular data required by following the links across the internet. The scraper, on the other hand, is a specific tool created to extract data from the website. The design of the scraper can vary greatly according to the complexity and scope of the project so that it can quickly and accurately extract the data.**bold text

# %% [markdown]
# In this project I have tried to find out the listings of various real estate mansions from 99acres.com. This project was completed on 1st, July, 2022, so anyone watching this project after 1st,July, 2022 would see a change from this particular output as there would be significant changes in the website with respect to time.

# %% [markdown]
# This project has been completed using the Python's BeautifulSoup library.

# %% [markdown]
# **Importing Necessary Dependencies**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **URL=https://www.99acres.com/property-in-kolkata-ffid
# This is the link of 99acres.com from which the data have been extracted.**

# %%
url="https://www.99acres.com/property-in-kolkata-ffid"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="" data-iswebp="false" data-reactroot="" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://static.99acres.com" rel="preconnect dns-prefetch"/>
#   <link href="https://mediacdn.99acres.com" rel="preconnect dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect dns-prefetch"/>
#   <link id="__tealBannerCss__" rel="stylesheet" type="text/css"/>
#   <link id="__recomCss__" rel="stylesheet" type="text/css"/>
#   <link id="__topDealerCss__" rel="stylesheet" type="text/css"/>
#   <script data-react-helmet="true" type="application/ld+json">
# ...

# %%
result=soup.find('div',class_="pageComponent srpTop__tuplesWrap")

# %%
print(result.prettify())
# Out:
# <div class="pageComponent srpTop__tuplesWrap" data-label="SEARCH" topmost="true">
#  <section data-hydration-on-demand="true">
#   <div class="srpTuple__cardWrap ">
#    <div class="pageComponent srpTuple__coWorkingTuple false srpTuple__noUspWithLandmark srpTuple__cardWrapPremium srp" data-custominfo='{"payload":{"search_results":{"selected_entity_tuples":[{"id":"63312340","rank":1}]}}}' data-label="FSL" data-rank="1_1" id="B63312340" topmost="true">
#     <div class=" srpTuple__tupleDetails srpTuple__premiumWrapper srpTuple__fsl">
#      <div class="pageComponent srpTuple__imageCont " data-label="PHOTO">
#       <div class="srpTuple__photonImgSec">
#        <div class="srpTuple__gallery false undefined">
#         <img alt="Ascon Era Others" datasrc="https://mediacdn.99acres.com/media1/18348/6/366966872M-1655703841681.jpg" decoding="async" height="100%" src="https://mediacdn.99acres.com/media1/18348/6/366966872M-1655703841681.jpg" width="100%"/>
#        </div>
#       </div>
# ...

# %%
"""Extracting the title described inside the anchor tag and defined in h2(heading) in the HTML document"""
 
ls=[]
for tag in soup.find_all('a',{"class":"body_med srpTuple__propertyName"}):
    ls.append(tag.text)
ls
# Out:
# ['2 BHK Apartment in Chinar Park',
#  '3 BHK Apartment in Kamalgazi',
#  '3 BHK Apartment in Garia Station',
#  '3 BHK Apartment in EM Bypass',
#  '3 BHK Apartment in EM Bypass Extension',
#  '2 BHK Apartment in EM Bypass Extension',
#  '1 BHK Apartment in EM Bypass Extension',
#  '3 BHK Apartment in Sonarpur',
#  '4 BHK Apartment in Entally',
#  '3 BHK Apartment in Narendrapur',
#  '2 BHK Apartment in Narendrapur',
#  '2 BHK Apartment in Sonarpur',
#  '2 BHK Apartment in Madhyamgram',
#  '3 Bedroom House in Diamond Harbour Road',
#  '3 BHK Apartment in Mankundu',
#  '2 BHK Apartment in Mankundu',
#  '2 BHK Apartment in Madhyamgram',
#  '2 BHK Apartment in Madhyamgram',
#  '4 Bedroom House in Joka',
#  '3 BHK Apartment in Howrah',
#  '3 Bedroom House in Joka',
#  '2 Bedroom House in Joka',
#  '3 BHK Apartment in Rajarhat',
#  '2 BHK Apartment in Rajarhat',
#  '4 BHK Apartment in Kasba',
#  '2 BHK Apartment in Joka',
#  '3 BHK Apartment in Rajarhat']

# %%
"""Extracting the description of the flat defined inside the anchor tag and defined inside the href tag"""

lst=[]
for tag in soup.find_all('a',id="srp_tuple_property_title"):
  lst.append(tag['href'])
lst
# Out:
# ['/2-bhk-bedroom-apartment-flat-for-sale-in-ascon-era-chinar-park-north-kolkata-913-sq-ft-to-1083-sq-ft-npspid-B63312340',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-symphony-serenity-kamalgachi-south-kolkata-1093-sq-ft-to-1120-sq-ft-npspid-Q63193652',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-subarna-residency-garia-station-south-kolkata-1365-sq-ft-to-1465-sq-ft-npspid-R63216604',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-laguna-bay-em-bypass-east-kolkata-1410-sq-ft-to-1589-sq-ft-npspid-I61762198',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-1064-sq-ft-to-1080-sq-ft-npspid-A63521350',
#  '/2-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-680-sq-ft-to-860-sq-ft-npspid-Z63521344',
#  '/1-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-500-sq-ft-to-514-sq-ft-npspid-O63521342',
# ...

# %%
len(ls)
# Out:
# 27

# %%
len(lst)
# Out:
# 27

# %%
lst1=ls
lst2=lst

# %%
lst1
# Out:
# ['2 BHK Apartment in Chinar Park',
#  '3 BHK Apartment in Kamalgazi',
#  '3 BHK Apartment in Garia Station',
#  '3 BHK Apartment in EM Bypass',
#  '3 BHK Apartment in EM Bypass Extension',
#  '2 BHK Apartment in EM Bypass Extension',
#  '1 BHK Apartment in EM Bypass Extension',
#  '3 BHK Apartment in Sonarpur',
#  '4 BHK Apartment in Entally',
#  '3 BHK Apartment in Narendrapur',
#  '2 BHK Apartment in Narendrapur',
#  '2 BHK Apartment in Sonarpur',
#  '2 BHK Apartment in Madhyamgram',
#  '3 Bedroom House in Diamond Harbour Road',
#  '3 BHK Apartment in Mankundu',
#  '2 BHK Apartment in Mankundu',
#  '2 BHK Apartment in Madhyamgram',
#  '2 BHK Apartment in Madhyamgram',
#  '4 Bedroom House in Joka',
#  '3 BHK Apartment in Howrah',
#  '3 Bedroom House in Joka',
#  '2 Bedroom House in Joka',
#  '3 BHK Apartment in Rajarhat',
#  '2 BHK Apartment in Rajarhat',
#  '4 BHK Apartment in Kasba',
#  '2 BHK Apartment in Joka',
#  '3 BHK Apartment in Rajarhat']

# %%
lst2
# Out:
# ['/2-bhk-bedroom-apartment-flat-for-sale-in-ascon-era-chinar-park-north-kolkata-913-sq-ft-to-1083-sq-ft-npspid-B63312340',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-symphony-serenity-kamalgachi-south-kolkata-1093-sq-ft-to-1120-sq-ft-npspid-Q63193652',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-subarna-residency-garia-station-south-kolkata-1365-sq-ft-to-1465-sq-ft-npspid-R63216604',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-laguna-bay-em-bypass-east-kolkata-1410-sq-ft-to-1589-sq-ft-npspid-I61762198',
#  '/3-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-1064-sq-ft-to-1080-sq-ft-npspid-A63521350',
#  '/2-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-680-sq-ft-to-860-sq-ft-npspid-Z63521344',
#  '/1-bhk-bedroom-apartment-flat-for-sale-in-gs-geetanjali-garden-em-bypass-extension-south-kolkata-500-sq-ft-to-514-sq-ft-npspid-O63521342',
# ...

# %%
#Extracting the name of the flat/residency

name=[]
for ele in lst2:
  #finding the index of the occurence of substring "in"
  ind=ele.find("in")
  name.append(ele[ind+3:ind+28])


name2=[]
for ele in name:
  #finding the second index of the occurence of "-"  in the string that is extracted 
  idx = ele.find('-', ele.find('-') + 1)
  name2.append(ele[:idx])
#name2

#removing the "-" from the string and extracting only the name of the residency/flat
final_lst=[]
for ele in name2:
    final_lst.append(ele.replace('-',' ').capitalize())
final_lst
# Out:
# ['Ascon era',
#  'Symphony serenity',
#  'Subarna residency',
#  'Laguna bay',
#  'Gs geetanjali',
#  'Gs geetanjali',
#  'Gs geetanjali',
#  'Ideal aurum',
#  'Mani crest',
#  'Sureka sunrise',
#  'Sureka sunrise',
#  'Ideal aurum',
#  'Master orchard',
#  'Ependent house',
#  'Parkwoods estate',
#  'Parkwoods estate',
#  'Bhawani bandhan',
#  'Master orchard',
#  'Ependent house',
#  'Periwal essense',
#  'Ependent house',
#  'Ependent house',
#  'Freshia rajarhat',
#  'Freshia rajarhat',
#  'Skdj signature',
#  'Solaris joka',
#  'Loharuka green']

# %%
#Finding out the number of BHK the residency/flat provides
ls_not_dig=[]
BHK=[]
for ele in lst1:
  if(ele[0].isdigit()):
    BHK.append(ele[0])
  else:
    BHK.append('0')
    ls_not_dig.append(len(BHK)-1)
ls_not_dig
# Out:
# []

# %%
#Finding the type of apartment/residency it is
type=[]
for ele in lst1:
  type.append(ele[1:16])

for ind in ls_not_dig:
  ele=lst1[ind]
  type[ind]=(ele[0:16])
type
# Out:
# [' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' Bedroom House ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' Bedroom House ',
#  ' BHK Apartment ',
#  ' Bedroom House ',
#  ' Bedroom House ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ',
#  ' BHK Apartment ']

# %%
#The physical location of the flat/apartment
loc=[]
for ele in lst1:
  ele.strip()
  l=ele.rfind('in')
  loc.append(ele[l+3:])
loc
# Out:
# ['r Park',
#  'Kamalgazi',
#  'Garia Station',
#  'EM Bypass',
#  'EM Bypass Extension',
#  'EM Bypass Extension',
#  'EM Bypass Extension',
#  'Sonarpur',
#  'Entally',
#  'Narendrapur',
#  'Narendrapur',
#  'Sonarpur',
#  'Madhyamgram',
#  'Diamond Harbour Road',
#  'Mankundu',
#  'Mankundu',
#  'Madhyamgram',
#  'Madhyamgram',
#  'Joka',
#  'Howrah',
#  'Joka',
#  'Joka',
#  'Rajarhat',
#  'Rajarhat',
#  'Kasba',
#  'Joka',
#  'Rajarhat']

# %%
#The area of the mansion in square foot both(minimum area and maximum area)

low_sqft=[]
high_sqft=[]
for ele in lst2:
  lf=ele.find('sq')
  rf=ele.rfind('sq')
  low_sqft.append(ele[lf-5:lf-1])
  high_sqft.append(ele[rf-5:rf-1])

cleaned_low_sqft=[]
for ele in low_sqft:
  cleaned_low_sqft.append(ele.replace('-',''))


cleaned_high_sqft=[]
for ele in high_sqft:
  cleaned_high_sqft.append(ele.replace('-',''))

for ind in ls_not_dig:
  ele=cleaned_low_sqft[ind]
  cleaned_low_sqft[ind]=ele.replace('a','')

# %%
#The advertisement reference

reference=[]
for ele in lst2:
  ri=ele.rfind('-')
  reference.append(ele[ri+1:])
reference
# Out:
# ['B63312340',
#  'Q63193652',
#  'R63216604',
#  'I61762198',
#  'A63521350',
#  'Z63521344',
#  'O63521342',
#  'F63081324',
#  'N62746658',
#  'S62416056',
#  'M62416052',
#  'F63081322',
#  'O63112952',
#  'G62002974',
#  'D63416762',
#  'H63416760',
#  'I61009200',
#  'P63112954',
#  'W62988176',
#  'P60670448',
#  'M62988172',
#  'B62988170',
#  'D63189178',
#  'L63189176',
#  'Z62585512',
#  'N62857268',
#  'T63506984']

# %% [markdown]
# **Creating a dictionary from the extracted data.**

# %%
#Creating a dictionary out of the values extracted
dict1={"BHK":BHK,"TYPE OF BUILDING":type,"FLAT NAME":final_lst,"LOCATION":loc,"MINIMUM SQFT":cleaned_low_sqft,"MAXIMUM SQFT":cleaned_high_sqft,"REFERENCE":reference}

# %% [markdown]
# **Converting the dictionary into an user friendly and readable Data Frame**

# %%
dict_to_df=pd.DataFrame.from_dict(dict1)

# %%
dict_to_df
# Out:
#    BHK TYPE OF BUILDING          FLAT NAME              LOCATION MINIMUM SQFT  \
# 0    2   BHK Apartment           Ascon era                r Park          913
# 1    3   BHK Apartment   Symphony serenity             Kamalgazi         1093
# 2    3   BHK Apartment   Subarna residency         Garia Station         1365
# 3    3   BHK Apartment          Laguna bay             EM Bypass         1410
# 4    3   BHK Apartment       Gs geetanjali   EM Bypass Extension         1064
# 5    2   BHK Apartment       Gs geetanjali   EM Bypass Extension          680
# 6    1   BHK Apartment       Gs geetanjali   EM Bypass Extension          500
# 7    3   BHK Apartment         Ideal aurum              Sonarpur         1175
# 8    4   BHK Apartment          Mani crest               Entally         2380
# 9    3   BHK Apartment      Sureka sunrise           Narendrapur          820
# 10   2   BHK Apartment      Sureka sunrise           Narendrapur          677
# ...
